# %% [markdown]
# <a href="https://colab.research.google.com/github/GiliardGodoi/tj-datasets/blob/main/notebooks/preprocessamento/01_Exemplo_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, userdata
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

from pathlib import Path

# %%
from ipywidgets import Box, Layout, Textarea, IntText, BoundedIntText

def display(df, index, left_column='conteudo', right_column='formatado'):
    # index = 9578 # @param {type:"number"}

    layout = Layout(width='550px', height='600px')
    left = Textarea(value=df.loc[index, left_column], layout=layout, description="Original:")
    right = Textarea(value=df.loc[index, right_column], layout=layout, description='Processado:')

    return Box([left, right])

# %%
INPUT_FOLDER = Path('/content/drive/Shareddrives/Projeto_TJSP_Datasets/Datasets/base_abril_2024/PREPROCESSED')
OUTPUT_FOLDER = Path('/content/drive/Shareddrives/Projeto_TJSP_Datasets/Datasets/base_abril_2024/PREPROCESSED')

base_33k_filepath = INPUT_FOLDER / "acordaos_principais_33k_Processado.parquet.gzip"
base_40k_filepath = INPUT_FOLDER / "acordaos_principais_40k_Processado.parquet.gzip"

assert base_33k_filepath.exists()
assert base_40k_filepath.exists()
assert OUTPUT_FOLDER.exists()

# %%
for f in INPUT_FOLDER.glob('*.parquet.gzip'):
    print(f.name)
# Out:
# acordaos_principais_33k_Fragmentos.parquet.gzip
# acordaos_principais_40k_Fragmentos.parquet.gzip
# acordaos_principais_33k_Processado.parquet.gzip
# acordaos_principais_33k_Fundamentacao_Decisao.parquet.gzip
# acordaos_principais_40k_Fundamentacao_Decisao.parquet.gzip
# acordaos_principais_40k_Processado.parquet.gzip
# acordaos_principais_33k_Sentences.parquet.gzip
# acordaos_principais_40k_Sentences.parquet.gzip
# acordaos_principais_33k_Segmentado.parquet.gzip
# acordaos_principais_40k_Segmentado.parquet.gzip
# acordaos_principais_33k_Segmentado_Normalizado.parquet.gzip
# acordaos_principais_40k_Segmentado_Normalizado.parquet.gzip

# %%
df = pd.read_parquet(OUTPUT_FOLDER / "acordaos_principais_33k_Processado.parquet.gzip")
df = df.loc[:500]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   numero_processo           501 non-null    object
#  1   id_documento              501 non-null    object
#  2   conteudo                  501 non-null    object
#  3   data_hora_documento       501 non-null    object
#  4   codigos_movimentos_temas  501 non-null    object
#  5   formatado_limpo           501 non-null    object
#  6   formatado_normalizado     501 non-null    object
# dtypes: object(7)
# memory usage: 27.5+ KB

# %%
df.head()
# Out:
#         numero_processo   id_documento  \
# 0  10042442520168260541   54994081 - 0
# 1  00272971919988260562   42752474 - 0
# 2  21140481120188260000   57226790 - 0
# 3  20924950520188260000  110484386 - 0
# 4  10130665020148260451   82218470 - 0
#
#                                             conteudo data_hora_documento  \
# 0  == PODER JUDICIÁRIO\na TRIBUNAL DE JUSTIÇA DO ...          2018-07-17
# 1   TRIBUNAL DE JUSTIÇA\n PODER JUDICIÁRIO\n São ...          2017-07-31
# 2   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2018-09-18
# 3   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2021-11-21
# 4   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2020-07-18
#
#   codigos_movimentos_temas                                    formatado_limpo  \
# 0                    85714  Registro: 2018.0000521991 ACÓRDÃO Vistos, rela...
# 1                    85721  Registro: 2017.0000544227 ACÓRDÃO Vistos, rela...
# ...

# %%
index = 59 # @param {type:"number"}

display(df, index, left_column='conteudo', right_column='formatado_limpo')
# Out:
# Box(children=(Textarea(value=" PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO ESTADO DE SÃO PAULO\nRegistro: 2022.0…

# %%
display(df, index, left_column='formatado_limpo', right_column='formatado_normalizado')
# Out:
# Box(children=(Textarea(value='Registro:2021.0000726918 ACÓRDÃO Vistos, relatados e discutidos destes autos do …

# %%
df2 = pd.read_parquet(OUTPUT_FOLDER / "acordaos_principais_33k_Fragmentos.parquet.gzip")
# df2 = df2.loc[:500]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33016 entries, 0 to 33015
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nome_relator           33016 non-null  object
#  1   nome_relator_regra     33016 non-null  int64
#  2   decisao_acordao        33016 non-null  object
#  3   decisao_acordao_regra  33016 non-null  int64
#  4   decisao_unanime        33016 non-null  bool
#  5   voto_relator           33016 non-null  object
#  6   voto_relator_regra     33016 non-null  int64
#  7   relatorio              28465 non-null  object
#  8   relatorio_regra        33016 non-null  int64
#  9   fundamentacao          28465 non-null  object
#  10  fundamentacao_regra    33016 non-null  int64
#  11  voto_divergente        2041 non-null   object
#  12  voto_divergente_regra  33016 non-null  int64
# dtypes: bool(1), int64(6), object(6)
# memory usage: 3.1+ MB

# %%
df2['decisao_acordao_regra'].value_counts()
# Out:
# decisao_acordao_regra
# 1    32854
# 2      161
# 3        1
# Name: count, dtype: int64

# %%
df2['voto_relator_regra'].value_counts()
# Out:
# voto_relator_regra
#  1    31659
# -2      873
#  2      378
#  3      106
# Name: count, dtype: int64

# %%
df2['fundamentacao_regra'].value_counts()
# Out:
# fundamentacao_regra
#  1    27625
# -1     4518
# -2      840
# -3       33
# Name: count, dtype: int64

# %%
df2['relatorio_regra'].value_counts()
# Out:
# relatorio_regra
#  1     28063
# -1      4551
#  2       187
#  7        98
#  13       41
#  6        36
#  8        14
#  10       11
#  11        5
#  12        5
#  3         3
#  9         2
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#            nome_relator  nome_relator_regra  \
# 0  carlos alberto lopes                   2
# 1           costa netto                   2
# 2  carlos alberto lopes                   2
# 3  joao batista vilhena                   2
# 4  joao batista vilhena                   2
#
#                                      decisao_acordao  decisao_acordao_regra  \
# 0   "deram provimento ao recurso. v. u.", de conf...                      1
# 1   "rejeitadas as preliminares, deram provimento...                      1
# 2   "deram provimento em parte ao recurso. v. u."...                      1
# 3   deram provimento em parte ao recurso. v. u., ...                      1
# 4   negaram provimento ao recurso do exequente, e...                      1
#
#    decisao_unanime                                       voto_relator  \
# 0             True  assinatura eletronica poder judiciario tribuna...
# 1             True  assinatura eletronica tribunal de justica pode...
# ...

# %%
index = 0 # @param {type:"number"}

display(df2, index, left_column='voto_relator', right_column='fundamentacao')
# Out:
# Box(children=(Textarea(value='assinatura eletronica poder judiciario tribunal de justica do estado de sao paul…

# %%
df3 = pd.read_parquet(OUTPUT_FOLDER / "acordaos_principais_33k_Fundamentacao_Decisao.parquet.gzip")
df3 = df3.loc[:500]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   numero_processo                      501 non-null    object
#  1   id_documento                         501 non-null    object
#  2   conteudo                             501 non-null    object
#  3   data_hora_documento                  501 non-null    object
#  4   codigos_movimentos_temas             501 non-null    object
#  5   formatado_fundamentacao              501 non-null    object
#  6   formatado_fundamentacao_normalizado  501 non-null    object
# dtypes: object(7)
# memory usage: 27.5+ KB

# %%
df3.head()
# Out:
#         numero_processo   id_documento  \
# 0  10042442520168260541   54994081 - 0
# 1  00272971919988260562   42752474 - 0
# 2  21140481120188260000   57226790 - 0
# 3  20924950520188260000  110484386 - 0
# 4  10130665020148260451   82218470 - 0
#
#                                             conteudo data_hora_documento  \
# 0  == PODER JUDICIÁRIO\na TRIBUNAL DE JUSTIÇA DO ...          2018-07-17
# 1   TRIBUNAL DE JUSTIÇA\n PODER JUDICIÁRIO\n São ...          2017-07-31
# 2   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2018-09-18
# 3   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2021-11-21
# 4   PODER JUDICIÁRIO\n TRIBUNAL DE JUSTIÇA DO EST...          2020-07-18
#
#   codigos_movimentos_temas                            formatado_fundamentacao  \
# 0                    85714   (o) recurso comporta provimento. nos termos d...
# 1                    85721   por proemio, afasta-se a arguicao de incompet...
# ...

# %%
index = 0 # @param {type:"number"}

display(df3, index, left_column='formatado_fundamentacao', right_column='formatado_fundamentacao_normalizado')
# Out:
# Box(children=(Textarea(value=' (o) recurso comporta provimento. nos termos da sumula nº 150 do supremo tribuna…

# %%
df4 = pd.read_parquet(OUTPUT_FOLDER / "acordaos_principais_33k_Segmentado.parquet.gzip")
df4 = df4.loc[:500]
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numero_processo   501 non-null    category
#  1   segmento_lei      501 non-null    object
#  2   segmento_fato     501 non-null    object
#  3   segmento_decisao  501 non-null    object
#  4   segmento_pedido   501 non-null    object
# dtypes: category(1), object(4)
# memory usage: 1.3+ MB

# %%
df4.head()
# Out:
#         numero_processo                                       segmento_lei  \
# 0  10042442520168260541  Carlos Alberto Lopes RELATOR Assinatura Eletrô...
# 1  00272971919988260562  Trata-se de recurso de apelação interposto, no...
# 2  21140481120188260000  Carlos Alberto Lopes RELATOR Assinatura Eletrô...
# 3  20924950520188260000  AGRAVO DE INSTRUMENTO EXPURGOS INFLACIONÁRIOS ...
# 4  10130665020148260451  Trata-se de recursos de apelação interpostos c...
#
#                                        segmento_fato  \
# 0  os artigos 82 e 83 do Código de Defesa do Cons...
# 1  Perícia realizada na unidade habitacional que ...
# 2  Carlos Alberto Lopes RELATOR Assinatura Eletrô...
# 3  AGRAVO DE INSTRUMENTO EXPURGOS INFLACIONÁRIOS ...
# 4  APELAÇÃO EXPURGOS INFLACIONÁRIOS AÇÃO CIVIL PÚ...
#
#                                     segmento_decisao  \
# 0  ACORDAM, em 18º Câmara de Direito Privado do T...
# 1  ACORDAM, em 9ª Câmara de Direito Privado do Tr...
# ...

# %%
index = 50 # @param {type: 'number'}

display(df4, index, left_column='segmento_lei', right_column='segmento_decisao')
# Out:
# Box(children=(Textarea(value='Regência do artigo 205 do CC/2002, não sendo hipótese de incidência do art. 206,…
